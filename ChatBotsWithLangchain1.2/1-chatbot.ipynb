# %%
import os 
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model = "llama-3.1-8b-instant", groq_api_key = groq_api_key)
model

# %%
from langchain_core.messages import HumanMessage
response = model.invoke([HumanMessage(content = "Hi , my name is mahesh and I'm a software engineer. What can you do ?")])
print(response.content)

# %%
from langchain_core.messages import AIMessage
model.invoke([HumanMessage(content = "Hi , my name is mahesh and I'm a software engineer. What can you do ?") , 
              AIMessage(content = ''' Nice to meet you, Mahesh. I'm an AI designed to assist and provide information on a wide range of topics. As a software engineer, you'll find my capabilities particularly useful. Here are some things I can do:

1. **Code reviews**: I can help you review your code, provide suggestions for improvements, and identify potential issues.
2. **Language-specific guidance**: I'm familiar with various programming languages, including Python, Java, C++, JavaScript, and more. I can help you with language-specific concepts, syntax, and best practices.
3. **Algorithm explanations**: I can explain complex algorithms, data structures, and software design patterns in a clear and concise manner.
4. **Troubleshooting**: If you're stuck on a particular problem or issue, I can help you troubleshoot and identify the root cause.
5. **Project ideas**: If you're looking for ideas for new projects or want to explore a specific area of interest, I can provide suggestions and resources.
6. **Technical explanations**: I can help you understand technical concepts, such as computer science fundamentals, software engineering principles, and emerging technologies like AI, ML, and blockchain.
7. **Best practices**: I can suggest best practices for software development, including coding standards, testing, and deployment.
8. **Book recommendations**: If you're looking to learn more about a specific topic or want to explore a new area, I can recommend books and online resources.
9. **Interview preparation**: I can help you prepare for technical interviews by providing practice problems, interview questions, and tips.
10. **General conversations**: We can have a conversation about software engineering, technology, or any other topic that interests you.

What specific area would you like to discuss or ask about, Mahesh? ''' ),
HumanMessage(content = "Hey what's my name and profession ?")
              ])

# %% [markdown]
# <h4>message history to understand the session management and how the model is able to remember the context of the conversation and respond accordingly. </h4>
#
# <p># -- we can use Message History class to wrap our model and keep it stateful and maintain the context of the conversation.
# # -- we can also use the message history to analyze the conversation and understand how the model is responding to different inputs and how it is able to maintain the context of the conversation over multiple turns.</p>

# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (1.2.17)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (2.0.47)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (0.7.9)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain_community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: certifi in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mahes\desktop\langgraph-tutorial\env-name\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)

# %%
from langchain_community.chat_message_histories import ChatMessageHistory 
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store={}
def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store or not isinstance(store[session_id], BaseChatMessageHistory):
        store[session_id] = ChatMessageHistory() 
    return store[session_id]

with_message_history = RunnableWithMessageHistory(model ,get_session_history)

# %%
config = {
    "configurable": {
            "session_id" : "chat1",
    }
}

# %%
with_message_history.invoke(
    [HumanMessage(content="Hi , my name is Mahesh and I'm a Software Developer /  AI engineer. What can you do ? ")],
    config = config 
)
# Out:
# AIMessage(content="Nice to meet you, Mahesh. As a Software Developer and AI engineer, you're likely familiar with the capabilities of AI models. I'm a large language model, trained on a massive dataset of text from various sources, allowing me to perform a wide range of tasks. Here are some examples of what I can do:\n\n1. **Answer questions**: I can process and respond to natural language queries on a vast range of topics, from science and history to entertainment and culture.\n2. **Generate text**: I can create human-like text based on a given prompt, style, or topic. This can be useful for content generation, writing assistance, or even creative writing.\n3. **Translate languages**: I can translate text from one language to another, including popular languages such as Spanish, French, German, Chinese, and many more.\n4. **Summarize content**: I can summarize long pieces of text into concise, bite-sized versions, highlighting key points and main ideas.\n5. **Provide definitions and explanations**: I can define technical terms, explain complex concepts, and provide detailed explanations on a wide range of topics.\n6. **Engage in conversations**: I can participate in natural-sounding conversations, using context and understanding to respond to questions and statements.\n7. **Solve math and logic problems**: I can perform mathematical calculations, solve algebraic equations, and even tackle more complex logical puzzles.\n8. **Generate ideas and suggestions**: I can help with brainstorming, suggesting ideas, and providing recommendations on topics such as product development, marketing, or creative projects.\n9. **Analyze and interpret data**: I can help with data analysis, providing insights and trends from large datasets, and even generating visualizations to illustrate key findings.\n10. **Learn and adapt**: I can learn from new data and adapt to changes in my knowledge base, ensuring that my responses stay up-to-date and accurate.\n\nAs a Software Developer and AI engineer, you might find my capabilities particularly useful for tasks such as:\n\n* Natural language processing (NLP) and machine learning (ML) related projects\n* Code review and suggestion\n* Technical writing and documentation\n* Research and development of new AI-powered applications\n* Troubleshooting and debugging AI-related issues\n\nWhat specific tasks or challenges would you like to discuss or work on, Mahesh?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 471, 'prompt_tokens': 603, 'total_tokens': 1074, 'completion_time': 0.485998438, 'completion_tokens_details': None, 'prompt_time': 0.035539543, 'prompt_tokens_details': None, 'queue_time': 0.046127256, 'total_time': 0.521537981}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ccc4e-0795-7561-bde8-c02a0c22cac3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 603, 'output_tokens': 471, 'total_tokens': 1074})

# %%
response.content
# Out:
# "Nice to meet you, Mahesh. I'm an AI designed to assist and provide information on a wide range of topics. As a software engineer, you'll find my capabilities particularly useful. Here are some things I can do:\n\n1. **Code reviews**: I can help you review your code, provide suggestions for improvements, and identify potential issues.\n2. **Language-specific guidance**: I'm familiar with various programming languages, including Python, Java, C++, JavaScript, and more. I can help you with language-specific concepts, syntax, and best practices.\n3. **Algorithm explanations**: I can explain complex algorithms, data structures, and software design patterns in a clear and concise manner.\n4. **Troubleshooting**: If you're stuck on a particular problem or issue, I can help you troubleshoot and identify the root cause.\n5. **Project ideas**: If you're looking for ideas for new projects or want to explore a specific area of interest, I can provide suggestions and resources.\n6. **Technical explanations**: I can help you understand technical concepts, such as computer science fundamentals, software engineering principles, and emerging technologies like AI, ML, and blockchain.\n7. **Best practices**: I can suggest best practices for software development, including coding standards, testing, and deployment.\n8. **Book recommendations**: If you're looking to learn more about a specific topic or want to explore a new area, I can recommend books and online resources.\n9. **Interview preparation**: I can help you prepare for technical interviews by providing practice problems, interview questions, and tips.\n10. **General conversations**: We can have a conversation about software engineering, technology, or any other topic that interests you.\n\nWhat specific area would you like to discuss or ask about, Mahesh?"

# %%
with_message_history.invoke(
    [HumanMessage(content="Hi , what's my name and profession ? ")],
    config = config 
)
# Out:
# AIMessage(content="Your name is Mahesh, and you're a Software Developer and AI Engineer.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 1093, 'total_tokens': 1110, 'completion_time': 0.010502238, 'completion_tokens_details': None, 'prompt_time': 0.073731927, 'prompt_tokens_details': None, 'queue_time': 0.056102733, 'total_time': 0.084234165}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ccc4e-1880-7d21-aa58-7f7168377f54-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1093, 'output_tokens': 17, 'total_tokens': 1110})

# %%
config1 = {
    "configurable": {
            "session_id" : "chat2",
    }
}
response = with_message_history.invoke(
    [HumanMessage(content="Hi , what's my name and profession ? ")],
    config = config1    
)
response.content
# Out:
# "I've already told you that I don't know your name and profession. I'm starting from a blank slate with each new conversation. If you'd like to introduce yourself, I'd be happy to get to know you."

# %%
response = with_message_history.invoke(
    [HumanMessage(content="Hi , I'm somu a B tech 3rd year student. What can you do ? ")],
    config = config1    
)
response.content
# Out:
# "Nice to meet you, Somu. As a B.Tech 3rd year student, you must be busy with your studies.\n\nI'm an AI designed to assist and communicate with users like you. Here are some things I can do:\n\n1. **Answer questions**: I can provide information on a wide range of topics, from science and history to entertainment and culture.\n2. **Generate text**: I can create text based on a prompt or topic, such as stories, articles, or even chat conversations like this one.\n3. **Translate languages**: I can translate text from one language to another, helping you communicate with people who speak different languages.\n4. **Summarize content**: I can summarize long pieces of text, such as articles or documents, into a concise and readable format.\n5. **Offer suggestions**: I can provide suggestions on topics like education, career, or personal development.\n6. **Play games**: I can engage in simple text-based games like 20 Questions, Hangman, or Word Chain.\n7. **Provide definitions**: I can define words and phrases, helping you understand unfamiliar terms.\n8. **Chat and converse**: I can have a conversation with you, responding to your questions and statements, and even generating creative responses.\n\nWhat would you like to talk about or try with me, Somu?"
